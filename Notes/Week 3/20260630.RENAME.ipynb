# %% [markdown]
# A metal sphere of radius $10cm$ is given a net charge of $-2.0nC$. If the sphere is touched to a neutral metal sphere of radius $20cm$, what is the net charge on the small sphere?
#
# $$\over{1}{2}$$

# %%
$LATEX$
# Out:
#   Cell In[2], line 1
#     $LATEX$
#     ^
# SyntaxError: invalid syntax
